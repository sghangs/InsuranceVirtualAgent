# %%
import os
import sys

# %%
sys.path.append("../..")

# %%
from src.workflow.graph import Graph

# %%
graph_obj=Graph()

# %%
from IPython.display import Image, display
graph = graph_obj.build_graph()
display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %%
import uuid
from langchain.schema import HumanMessage

# %%
user_input = "Hello!"
thread_id = str(uuid.uuid4())
policy_number = "AU1234"
message = [HumanMessage(content=user_input)]
config = {"configurable":{"thread_id":thread_id}}
response = graph.invoke({"messages":message,"policy_number":policy_number},config)
for m in response['messages']:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Hello!
# ================================== Ai Message ==================================
#
# Hello! How can I assist you today? If you have any questions or need assistance, feel free to ask.

# %%
user_input = "My name is Sunny. I want to know about my policy."
policy_number = "AU1234"
message = [HumanMessage(content=user_input)]
response = graph.invoke({"messages":message,"policy_number":policy_number},config)
for m in response['messages']:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Hello!
# ================================== Ai Message ==================================
#
# Hello! How can I assist you today? If you have any questions or need assistance, feel free to ask.
# ================================ Human Message =================================
#
# My name is Sunny. I want to know about my policy.
# ================================== Ai Message ==================================
# Tool Calls:
#   hybrid_retriever (call_uPZgAQD1iGyvR8swlwX7S3Z2)
#  Call ID: call_uPZgAQD1iGyvR8swlwX7S3Z2
#   Args:
#     query: I want to know about my policy.
#     policy_number: AU1234
# ================================= Tool Message =================================
# Name: hybrid_retriever
#
# ["# Home Insurance\n\nIf you want to know what information is held about you by Inter Partner Assistance or AXA Assistance (UK) Limited, please write to us at:\n\nData Protection Officer  \nAXA Assistance UK Limited  \nThe Quadrangle  \n106-118 Station Road  \nRedhill  \nSurrey  \nRH1 1PR  \n\nThere may be a charge for this service, as permitted by law. Any information which is found to be incorrect will be corrected promptly. Information about you is only held for so long as it is appropriate for the above.\n\n----\n\n## Making a Complaint\n\nWe aim to provide the highest standard of service to every customer.\n\nIf our service does not meet your expectations, we want to hear about it so we can try to put things right.\n\nAll complaints we receive are taken seriously. The following will help us to understand your concerns and give you a fair response.\n\n### Making your complaint\n\nPlease write to:\n\nCustomer Relations  \nAXA Assistance UK Ltd  \nThe Quadrangle  \n106-118 Station Road  \nRedhill  \nSurrey  \nRH1 1PR  \n\nTel: 01737 815913  \nEmail: homeemergencycomplaints@axa-assistance.co.uk  \n\nShould you remain dissatisfied following our final written response, you may be eligible to refer your case to the Financial Ombudsman Service at the address given below.\n\nThe Financial Ombudsman Service is an independent body that arbitrates on complaints about general insurance products.\n\nYou have six months from the date of our final response to refer your complaint to the Financial Ombudsman Service. This does not affect your right to take legal action.", "# Essential Information\n\n## General Conditions\n\nThese general conditions apply throughout your policy.\n\nHome Assistance and Family Legal Protection covers have additional conditions (see relevant sectional conditions).\n\n**You and your family** must comply with these conditions to have full protection of your policy.\n\nIf **you or your family** do not comply with them we may cancel the policy, refuse to deal with any relevant claims or reduce the amount of any relevant claim payments.\n\n### Your Policy\n\n*please see the Definitions section*\n\nAXA Home Insurance is underwritten by AXA Insurance UK plc which is authorised by the Prudential Regulation Authority and regulated by the Financial Conduct Authority and the Prudential Regulation Authority under Financial Services Register number 202312. You can check this on the Financial Services Register by visiting the FCA’s website at www.fca.org.uk\n\nYou must make sure that all the information you have given us as part of your application is true and complete to the best of your knowledge and belief. Failure to do so could result in your policy being cancelled or could result in any relevant claims being reduced or refused.\n\nIn return for having accepted your premium we will in the event of injury, loss or damage happening during the period of insurance provide insurance as described in the section wordings and essential information document and referred to in your schedule.\n\nPlease read your policy to make sure that you are satisfied with your insurance. If you have any questions please contact us.\n\n### The law which applies to this Policy\n\n**You and we** can choose the law which applies to this policy. We propose that the law of England and Wales applies. Unless we and you agree otherwise the law of England and Wales will apply to this policy.\n\n### Legal Helpline\n\n**You** can contact the legal helpline on 0330 024 1278* for advice on any personal legal or tax problem directly affecting you. Please quote ‘AXA Direct’. Advice will not be provided about your business, trade or profession. The legal helpline is available 24 hours a day 365 days a year. The tax helpline is available between 9am and 5pm Monday to Friday (other than public holidays). The advice available from the helpline is limited to the law of the United Kingdom, the Channel Islands and the Isle of Man except the tax helpline which is li ...
# ================================== Ai Message ==================================
#
# Hello Sunny! I'd be happy to help you understand your policy. Here’s a brief overview based on the context provided:
#
# 1. **Policy Components**: Your policy consists of several parts, including your Schedule, Section Wordings, and Essential Information, which cover conditions and exclusions, definitions, claims conditions, and how to make a complaint.
#
# 2. **General Conditions**: It's essential to comply with the general conditions to maintain full protection. This includes ensuring all information you provide is true and complete. Non-compliance could lead to your policy being canceled or claims being denied or reduced.
#
# 3. **Insurance Provider**: Your home insurance is underwritten by AXA Insurance UK plc, regulated by relevant authorities.
#
# 4. **Legal Helpline**: You can access a 24/7 legal advice helpline for personal legal or tax problems under the laws of the UK, Channel Islands, and Isle of Man.
#
# 5. **Key Terms Defined**:
#    - **Storm**: Includes specific weather conditions like wind speeds of 48 knots or more, torrential rain, heavy snowfall, or intense hail.
#    - **Subsidence**: Refers to the downward movement of your building's site, not due to natural settlement.
#    - **Unfurnished/Unoccupied**: Definitions are provided for these circumstances, affecting your policy if your property is vacant or lacks furnishings for over 30 days.
#    - **Valuables and Vermin**: Specific definitions are given for what counts as valuables and what animals are considered vermin.
#
# 6. **Applicable Law**: Unless otherwise agreed, the law of England and Wales applies to your policy.
#
# If you have further questions or need detailed information on a particular section of your policy, please let me know!

# %%
user_input = "Do you remember me?"
policy_number = "AU1234"
message = [HumanMessage(content=user_input)]
response = graph.invoke({"messages":message,"policy_number":policy_number},config)
for m in response['messages']:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Hello!
# ================================== Ai Message ==================================
#
# Hello! How can I assist you today? If you have any questions about your insurance policy or need information on general topics, feel free to ask.
# ================================ Human Message =================================
#
# My name is Sunny. I want to know about my policy.
# ================================== Ai Message ==================================
# Tool Calls:
#   hybrid_retriever (call_XNUftBPYz1haRGxlKe5asHSA)
#  Call ID: call_XNUftBPYz1haRGxlKe5asHSA
#   Args:
#     query: details about my policy
#     policy_number: AU1234
# ================================= Tool Message =================================
# Name: hybrid_retriever
#
# ["# Home Insurance\n\n## Personal Possessions (optional extra)\n\n**Your policy schedule will show if you have chosen this section.**\n\n| What your policy covers:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    | What your policy does cover:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |\n| ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# ================================== Ai Message ==================================
#
# Hello Sunny! To learn more about your home insurance policy, you'll need to refer to your policy schedule, which outlines the specifics of what your coverage includes. Here are some key points from the provided context:
#
# ### Personal Possessions Coverage
# - Your personal possessions coverage is an optional extra, indicated in your policy schedule.
# - This covers personal effects, valuables, and money belonging to you or your family, mainly for private use.
# - The coverage extends to anywhere in Europe, Jordan, Madeira, the Canary and Mediterranean islands, and countries bordering the Mediterranean. Additionally, it applies worldwide for up to 60 days per insurance period as listed in your schedule.
#
# ### What is Not Covered
# - Losses arising from issues like remaking films, discs, or tapes.
# - Damages caused during cleaning, maintenance, or repair.
# - Damages from pets or vermin, and theft from unattended vehicles unless secured.
# - Damages to motorized vehicles/crafts or business-related properties.
# - Loss of plants, living creatures, documents, or from fraudulent payment methods.
#
# ### Automatic Renewals
# - Your policy is set to auto-renew via a continuous payment authority unless you instruct otherwise.
# - You will be notified 21 days before the renewal date where you can opt to continue or cancel.
#
# ### Cancelling Your Policy
# - You can cancel within 14 days of receipt of the policy or its start date for a full refund minus a £15 fee, assuming no claim has been made.
# - Cancellation after this period may incur a £25 fee, with refunds proportional to the unused term if no claims have been made.
#
# If you need specific details about sums insured, limits, or need to make changes, it's best to log into your AXA account or contact them directly. Let me know if you need help with anything else!
# ================================ Human Message =================================
#
# Do you remember me?
# ================================== Ai Message ==================================
#
# Hello Sunny! I don't have memory of past interactions, but I'm here to help you with any questions you may have related to your policy or insurance in general. If you need specific details about your policy, please let me know what information you're looking for, and I can help retrieve the relevant details.

# %%
user_input = "What is my name?"
policy_number = "AU1234"
message = [HumanMessage(content=user_input)]
response = graph.invoke({"messages":message,"policy_number":policy_number},config)
for m in response['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   hybrid_retriever (call_XNUftBPYz1haRGxlKe5asHSA)
#  Call ID: call_XNUftBPYz1haRGxlKe5asHSA
#   Args:
#     query: details about my policy
#     policy_number: AU1234
# ================================= Tool Message =================================
# Name: hybrid_retriever
#
# ["# Home Insurance\n\n## Personal Possessions (optional extra)\n\n**Your policy schedule will show if you have chosen this section.**\n\n| What your policy covers:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    | What your policy does cover:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |\n| ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# ================================ Human Message =================================
#
# What is my name?
# ================================== Ai Message ==================================
#
# Your name is Sunny. How can I assist you further with your insurance policy today?
